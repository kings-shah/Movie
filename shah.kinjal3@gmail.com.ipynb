# %% [markdown]
# <p align="center"><img src="https://github.com/insaid2018/Term-1/blob/master/Images/INSAID_Full%20Logo.png?raw=true" width="260" height="110" /></p>

# %% [markdown]
# ---
# # **Table of Contents**
# ---
#
# 1. [**Introduction**](#Section1)<br>
# 2. [**Problem Statement**](#Section2)<br>
# 3. [**Installing & Importing Libraries**](#Section3)<br>
#   3.1 [**Installing Libraries**](#Section31)<br>
#   3.2 [**Upgrading Libraries**](#Section32)<br>
#   3.3 [**Importing Libraries**](#Section33)<br>
# 4. [**Data Acquisition & Description**](#Section4)<br>
# 5. [**Data Pre-Profiling**](#Section5)<br>
# 6. [**Data Pre-Processing**](#Section6)<br>
#   6.1 [**Changing col names to lower case**](#Section11)<br>
#   6.2 [**Changing column names**](#Section12)<br>
#   6.3 [**Create new Genre column**](#Section13)<br>
#   6.4 [**Drop 'description' column**](#Section14)<br>
#   6.5 [**Handling null values in Revenue column**](#Section15)<br>
#   6.6 [**Removing null from the 'metascore' column**](#Section16)<br>
#   6.7 [**Create new 4 Actor column**](#Section17)<br>
# 7. [**Data Post-Profling**](#Section7)<br>
# 8. [**Exploratory Data Analysis**](#Section8)<br>
#   8.1 [**How many movies were released every year?**](#Section18)<br>
#   8.2 [**How many movies were released in genre in total?**](#Section19)<br>
#   8.3 [**How much revenue was generated per Genre?**](#Section20)<br>
#   8.4 [**To dig deeper into genre and revenue**](#Section21)<br>
#   8.5 [**Which Genre is most profitale?**](#Section22)<br>
#   8.6 [**Correlation between revenue & oher parameters like rating, votes & metascore**](#Section23)<br>
#   8.7 [**Does a higher  movie rating predict a higher profit?**](#Section24)<br>
#   8.8 [**What should the ideal runtime of a movie be?**](#Section25)<br>
#   8.9 [**Which actors should be prefered for a Sci-fi & Fantasy/Adventure & Action movies?**](#Section26)<br>
#   8.10[**Are certain movie directors especially good at a particular genre (in terms of profit)?**](#Section27)<br>
# 9. [**Summarization**](#Section9)</br>
#   9.1 [**Conclusion**](#Section91)</br>
#   9.2 [**Actionable Insights**](#Section91)</br>
#
# ---

# %% [markdown]
# ---
# <a name = Section1></a>
# # **1. Introduction**
# ---
# <p align="center"><img src="lionsgate_logo.jpg"></p>
# Lionsgate Films is the most commercially successful mini-major movie and television distribution company in North America as well as the seventh most profitable movie studio.
#
# Lionsgate has its origins go back to 1962 with the founding of Cinépix in Montreal. They would be purchased by the Lion Gate Entertainment Group in 1997 to form the studio as it is known today. They have succeeded through the help of other studios they have acquired such as Trimark Pictures, Vestron Pictures and Artisan Entertainment.
# There is no telling where Lionsgate will be in the future but I would imagine if they keep up with their smart investments they may soon make the transition to becoming a major studio. All they need is time!
# Lionsgate have helped produce some great movies series like Kick-Ass, The Expendables and The Hunger Games.
# <b>The studio does not currently have any of their films in the ranking of top 50 highest grossing films.</b>

# %% [markdown]
# ---
# <a name = Section2></a>
# # **2. Problem Statement**
# ---
#
# - What would the world be like without movies? Well, the quick answer would be a lot less entertaining. Movies make us laugh, cry, jump with joy and grab the nearest pillow in fear.
#
# The production companies fund the making of movies and offer the resources and manpower required to make it all possible. It is exciting to look back over the past hundred years and look at the great films that have been produced by some of the most influential production companies in the world.
# Among the few top Production houses are:
# <ul>
# <li>Warner Bros. is an unstoppable production company that has not only created some great movies but also some great film franchises. Among these are Harry Potter, The Matrix and Batman.</li>
# <li>Sony is considered to have the biggest studio today,they have produced some great movies over the years as well as some franchises like Spider-Man, Men in Black and Resident Evil.</li>
# <li>Walt Disney Studios is the entertainment unit of The Walt Disney Company. The studio has produced some great movies over the years that have impacted many peoples lives, especially younger audiences.Their films include Pirates of the Caribbean, Beauty and the Beast and The Jungle Book</li>
# <li>Universal Studios has produced some timeless classics over the years. Their major box office hits include Jurassic Park, E.T. the Extra-Terrestrial and Jaws, which were all directed by Steven Spielberg</li>
# <li>20th Century Fox is one of the Big Six studios.They have produced some amazing and successful franchises. Among them are Ice Age,Avatar and X-Men</li>
# <li>Lionsgate Films is the most commercially successful mini-major movie and television distribution company in North America as well as the seventh most profitable movie studio.
# <i><b>Lionsgate want to climb up the ladder and see many of their movies in top 50 list.
# They want to find out which movies have earned the highest revenue over the years which will help them to pick their new projects</i></b></li>
# </ul>

# %% [markdown]
# ---
# <a id = Section3></a>
# # **3. Installing & Importing Libraries**
# ---
#
# - This section is emphasised on installing and importing the necessary libraries that will be required.

# %% [markdown]
# ### **Installing Libraries**

# %%
# !pip install -q datascience                                         # Package that is required by pandas profiling
# !pip install -q pandas-profiling                                    # Library to generate basic statistics about data
# To install more libraries insert your code here..
# Out:
# ERROR: Invalid requirement: '#'
# ERROR: Invalid requirement: '#'

# %% [markdown]
# ### **Upgrading Libraries**
#
# - **After upgrading** the libraries, you need to **restart the runtime** to make the libraries in sync.
#
# - Make sure not to execute the cell under Installing Libraries and Upgrading Libraries again after restarting the runtime.

# %%
# !pip install -q --upgrade pandas-profiling                          # Upgrading pandas profiling to the latest version
# Out:
# ERROR: Invalid requirement: '#'

# %% [markdown]
# ### **Importing Libraries**
#
# - You can headstart with the basic libraries as imported inside the cell below.
#
# - If you want to import some additional libraries, feel free to do so.

# %%
#-------------------------------------------------------------------------------------------------------------------------------
import pandas as pd                                                 # Importing package pandas (For Panel Data Analysis)
from pandas_profiling import ProfileReport                          # Import Pandas Profiling (To generate Univariate Analysis)
#-------------------------------------------------------------------------------------------------------------------------------
import numpy as np                                                  # Importing package numpys (For Numerical Python)
#-------------------------------------------------------------------------------------------------------------------------------
import matplotlib.pyplot as plt                                     # Importing pyplot interface to use matplotlib
import seaborn as sns                                               # Importing seaborn library for interactive visualization
# %matplotlib inline
#-------------------------------------------------------------------------------------------------------------------------------
import scipy as sp                                                  # Importing library for scientific calculations
#-------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ---
# <a name = Section4></a>
# # **4. Data Acquisition & Description**
# ---
#
# - This section is emphasised on the accquiring the data and obtain some descriptive information out of it.
#
# - You could either scrap the data and then continue, or use a direct source of link (generally preferred in most cases).
#
# - You will be working with a direct source of link to head start your work without worrying about anything.
#
# - Before going further you must have a good idea about the features of the data set:
#
# |Id|Feature|Description|
# |:--|:--|:--|
# |01|Rank|Movie Rank|
# |02| Title | Title of the movie|
# |03| Genre | The various Genre that the movie can be associated with|
# |04| Description| Short description about the movie|
# |05| Director| Director of the movie|
# |06| Actors| Main actors in the movie|
# |07| Year| Year in which the movie was released|
# |08| Runtime (minutes)| Total movie playing time|
# |09| Rating | Movie rating|
# |10| Votes| Vores for the movie|
# |11| Revenue (Millions)| Revenue by the movie (in millions)|
# |12| Metascore| Is the score of the movie on the metacritic website by critics|

# %%
data = pd.read_csv(filepath_or_buffer = 'https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/1000%20movies%20data.csv')
print('Data Shape:', data.shape)
data.head()
# Out:
# Data Shape: (1000, 12)
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %% [markdown]
# ### **Data Description**
#
# - To get some quick description out of the data you can use describe method defined in pandas library.

# %%
data.describe(include='all')
# Out:
#                Rank     Title                    Genre  \
# count   1000.000000      1000                     1000
# unique          NaN       999                      207
# top             NaN  The Host  Action,Adventure,Sci-Fi
# freq            NaN         2                       50
# mean     500.500000       NaN                      NaN
# std      288.819436       NaN                      NaN
# min        1.000000       NaN                      NaN
# 25%      250.750000       NaN                      NaN
# 50%      500.500000       NaN                      NaN
# 75%      750.250000       NaN                      NaN
# max     1000.000000       NaN                      NaN
#
#                                               Description      Director  \
# count                                                1000          1000
# unique                                               1000           644
# top     After a stint in a mental institution, former ...  Ridley Scott
# ...

# %% [markdown]
# <b>Observations</b>
# <ul>
#     <li>Genre has 207 unique values. Usually there are 6-7 major genre. We need to fix it.</li>
#     <li>Description has 1000 uniquie values. Its mainly text. Need to drop it.</li>
#     <li>Director has 664 unique values. Riddley has max no. of movies directed</li>
#     <li>Actor's column has 996 uniquie values. The actor's names are comma separated</li>
#     <li>Runtime and Rating mean and median are almost the same.</li>
#     <li>Revenue and Meta score have missing values</li>
#     <li>Revenue has outlier as 936 is quite higher than mean and median</li>
#
# </ul>

# %% [markdown]
# ### **Data Information**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %% [markdown]
# ---
# <a name = Section5></a>
# # **5. Data Pre-Profiling**
# ---
#
# - This section is emphasised on getting a report about the data.
#
# - You need to perform pandas profiling and get some observations out of it...

# %%
# !pip install pandas-profiling --upgrade
# Out:
# Requirement already up-to-date: pandas-profiling in c:\users\toshia\anaconda3\lib\site-packages (3.0.0)
# ...

# %%
import pandas_profiling 

profile = data.profile_report(title="Movie Data Analysis", progress_bar=False, minimal=True)
profile.to_file(output_file="movie_data_analysis.html")

# %% [markdown]
# **Observations from Pandas Profiling before Data Processing** <br><br>
# __Dataset info__:
# - Number of variables: 12
# - Number of observations: 1000
# - Missing cells: 192 (1.6%)
#
#
# __Variables types__:
# - Numeric = 7
# - Categorical = 5
# - Text (Unique) = 1
# <br>
#
# - **Title has a high cardinality: 999 distinct values**.
#
#
# - **Genre has a high cardinality: 207 distinct values**.
#
#
# - **Revenue** is **highly correlated** with **Votes**.
#
#
# - **Votes** is **highly correlated** with **Rating,Metascore**.
#
#
# - **Rating** is **highly correlated** with **Metascore,Runtime**.
#
#
# - **Description has a high cardinality: 1000 distinct values**.
#
#
# - **Director has a high cardinality: 644 distinct values**.
#
#
# - **Actors has a high cardinality: 996 distinct values**.
#
#
# - **Revenue (Millions) has 128 (12.8%) missing values**.
#
#
# - **Metascore has 64 (6.4%) missing values**.

# %% [markdown]
# ---
# <a name = Section6></a>
# # **6. Data Pre-Processing**
# ---

# %% [markdown]
# <a name = Section11></a>
# <b>Changing column names to lower case<b>

# %%
data.columns = map(str.lower, data.columns)    # changing col names to lowercase

# %% [markdown]
# <a name = Section12></a>
# ###### Changing column names of Revenue (Millions) to 'revene' and Runtime (Minutes) to 'runtime' as the space in the name can give an error

# %%
data = data.rename(columns = {"revenue (millions)":"revenue","runtime (minutes)":"runtime"})
data.columns
# Out:
# Index(['rank', 'title', 'genre', 'director', 'actors', 'year', 'runtime',
#        'rating', 'votes', 'revenue', 'metascore', 'genre_new', 'actor1',
#        'actor2', 'actor3', 'actor4', 'runtime_group'],
#       dtype='object')

# %% [markdown]
# <a name = Section13></a>
# ###### Creating Genre_new column
# Genre is very important for the analysis of which kind of project Liongates whould take up that will give them higher revenue at the Box Office. As we have observed that the genre column has a combination of multiple genres. So we are creating a new column 'genre_new' and will put each movie in their respective genre to avoid amiguity.

# %%
adventure_action=['Action,Adventure,Romance','Adventure,Drama,History', 'Action,Adventure,Western','Action,Adventure,Comedy','Action,Adventure,Drama','Adventure,Drama,Thriller','Animation,Adventure,Comedy', 'Action,Adventure,Biography', 'Adventure,Drama,Romance','Adventure,Comedy,Family','Adventure,Comedy','Adventure,Biography,Drama','Animation,Adventure,Family','Adventure,Comedy,Drama','Adventure,Crime,Mystery','Adventure,Comedy,Romance','Adventure,Drama,Family','Adventure,Drama,War','Adventure,Comedy','Adventure,Drama,Western','Adventure,Drama', 'Adventure','Adventure,Biography', 'Adventure,Biography,Crime','Adventure,Family','Action,Drama,War','Action,Crime,Thriller', 'Action,Crime,Drama','Action,Thriller','Action,Comedy,Drama','Action,Crime,Sport','Action,Crime,Mystery','Action,Mystery,Thriller','Action,Biography,Crime','Action,Comedy,Family','Animation,Action,Adventure','Action,Adventure','Action,Adventure,Mystery','Action,Drama,Sport','Action,Adventure,Family', 'Action,Comedy','Action,Drama,History','Action,Adventure,Thriller','Action,Comedy,Mystery','Action,Drama,Mystery', 'Action,Adventure,Crime','Action','Action,Biography,Drama','Action,Comedy,Crime','Action,Drama,Romance','Animation,Action,Comedy','Action,Comedy,Romance','Action,Drama,Family','Action,Thriller,War','Action,Comedy,Sport','Action,Drama,Thriller']
thriller=['Drama,Mystery,War','Drama,Thriller','Thriller','Biography,Drama,Thriller','Thriller,War','Mystery,Thriller','Mystery,Thriller,Western','Crime,Mystery,Thriller','Crime,Drama,Thriller','Drama,Mystery,Thriller','Biography,History,Thriller', 'Drama,Thriller,War','Biography,Drama,Mystery','Mystery,Romance,Thriller','Biography,Drama,Mystery','Crime,Thriller','Drama,History,Thriller','Crime,Drama,Mystery']
horror=['Drama,Horror,Thriller','Action,Comedy,Horror','Horror','Action,Horror,Sci-Fi','Crime,Horror,Thriller','Crime,Drama,Horror','Horror,Thriller','Action,Horror,Mystery','Adventure,Horror,Mystery','Action,Adventure,Horror','Action,Horror,Romance','Comedy,Drama,Horror','Comedy,Fantasy,Horror','Adventure,Comedy,Horror','Comedy,Horror','Drama,Horror,Sci-Fi','Action,Horror', 'Comedy,Horror,Thriller','Action,Drama,Horror','Drama,Horror','Horror,Sci-Fi,Thriller','Drama,Fantasy,Horror','Horror,Mystery','Adventure,Horror','Adventure,Drama,Horror','Drama,Horror,Mystery','Action,Horror,Thriller','Horror,Mystery,Sci-Fi','Horror,Mystery,Thriller','Fantasy,Horror','Action,Fantasy,Horror','Fantasy,Horror,Thriller','Drama,Horror,Musical','Comedy,Horror,Romance','Comedy,Horror,Sci-Fi','Horror']
drama=['Drama','Biography,Drama','Biography,Drama,History','Drama,Sport','Crime,Drama,Music','Biography,Drama,Sport','Crime,Drama,History','Drama,War','Drama,Western','Drama,Music','Biography,Crime,Drama','Crime,Drama','Drama,History','Drama,History,War','Drama,Family','Biography,Drama,Family', 'Drama,Family,Music']
comedy=['Comedy,Drama','Comedy,Drama,Music', 'Comedy','Animation,Comedy,Family','Comedy,Drama,Family','Comedy,Music','Comedy,Mystery','Comedy,Crime','Comedy,Family','Biography,Comedy,Drama','Comedy,Drama,Thriller','Comedy,Crime,Thriller','Comedy,Family,Musical','Comedy,Crime,Drama','Biography,Comedy,Crime','Comedy,Western','Animation,Comedy,Drama','Comedy,Drama,Musical']
sci_fant=['Mystery,Sci-Fi,Thriller','Drama,Sci-Fi,Thriller','Sci-Fi,Thriller','Crime,Drama,Fantasy','Drama,Fantasy,Music','Adventure,Sci-Fi,Thriller','Drama,Fantasy,Thriller','Adventure,Drama,Fantasy','Animation,Family,Fantasy','Romance,Sci-Fi,Thriller','Drama,Mystery,Sci-Fi','Comedy,Sci-Fi','Drama,Sci-Fi','Drama,Fantasy,War','Romance,Sci-Fi','Sci-Fi','Drama,Family,Fantasy','Drama,Romance,Sci-Fi','Drama,Fantasy','Animation,Drama,Fantasy','Drama,Fantasy,Romance','Adventure,Drama,Sci-Fi','Action,Drama,Fantasy','Adventure,Family,Fantasy','Action,Adventure,Fantasy','Adventure,Mystery,Sci-Fi','Drama,Fantasy,Musical','Action,Adventure,Sci-Fi','Adventure,Fantasy','Action,Mystery,Sci-Fi','Action,Crime,Fantasy','Action,Sci-Fi,Thriller','Action,Fantasy','Action,Fantasy,War','Action,Comedy,Fantasy','Action,Sci-Fi','Action,Fantasy,Thriller','Comedy,Family,Fantasy','Adventure,Comedy,Sci-Fi','Drama,Fantasy,Mystery','Adventure,Comedy,Fantasy','Adventure,Fantasy,Mystery','Adventure,Fantasy,Mystery','Action,Drama,Sci-Fi','Mystery,Romance,Sci-Fi','Animation,Fantasy','Action,Comedy,Sci-Fi','Action,Crime,Sci-Fi','Comedy,Fantasy,Romance', 'Comedy,Fantasy', 'Comedy,Drama,Fantasy','Fantasy,Mystery,Thriller']
romance=['Comedy,Family,Romance','Comedy,Drama,Romance','Comedy,Romance,Sport','Drama,Romance,Thriller','Drama,Music,Romance','Drama,Romance,War','Comedy,Romance,Western','Comedy,Music,Romance','Animation,Drama,Romance','Comedy,Romance','Biography,Drama,Romance','Drama,Musical,Romance','Drama,Mystery,Romance','Drama,Romance']

# %%
def gender_fun(g):
    if g in adventure_action:
        return 'Adventure & Action'
    elif g in romance:
        return 'Romance'
    elif g in thriller:
        return 'Thriller & Mystry'
    elif g in horror:
        return 'Horror'
    elif g in drama:
        return 'Drama'
    elif g in comedy:
        return 'Comedy'
    elif g in sci_fant:
        return 'Sci-fi & Fantasy'
data['genre_new']=data['genre'].apply(gender_fun)

# %%
data.head()
# Out:
#    rank                    title                     genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                director                                             actors  \
# 0            James Gunn  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# 1          Ridley Scott  Noomi Rapace, Logan Marshall-Green, Michael Fa...
# 2    M. Night Shyamalan  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# 3  Christophe Lourdelet  Matthew McConaughey,Reese Witherspoon, Seth Ma...
# 4            David Ayer  Will Smith, Jared Leto, Margot Robbie, Viola D...
#
#    year  runtime  rating   votes  revenue  metascore         genre_new  \
# 0  2014      121     8.1  757074   333.13       76.0  Sci-fi & Fantasy
# ...

# %% [markdown]
# <a name = Section14></a>
# ###### Drop 'description' column
# Description column has 1000 unique values of textual lines wich will be of no use for the analysis

# %%
data.drop(['description'],axis=1,)

# %% [markdown]
# <a name = Section15></a>
# ###### Handling null values in Revenue colmn.
# We oserved that revenue col is affected by the rating. Movies with rating aove 6 have more revenue than movies with rating below 6. So we will replace the null values with median of revene according to the genre

# %%
for (row,col) in data.iterrows():
    if (col.genre_new=='Drama')& (col.rating>=6.0) & (pd.isnull(col.revenue)):
        data.loc[row,'revenue']=15.96
    if (col.genre_new=='Drama')& (col.rating<6.0) & (pd.isnull(col.revenue)):
        data.loc[row,'revenue']=25.98
    if (col.genre_new=='Horror')& (col.rating>=6.0) & (pd.isnull(col.revenue)):
        data.loc[row,'revenue']=29.85
    if (col.genre_new=='Horror')& (col.rating<6.0) & (pd.isnull(col.revenue)):
        data.loc[row,'revenue']=25.92
    if (col.genre_new=='Thriller & Mystry')& (col.rating>=6.0) & (pd.isnull(col.revenue)):
        data.loc[row,'revenue']=32.07
    if (col.genre_new=='Thriller & Mystry')& (col.rating<6.0) & (pd.isnull(col.revenue)):
        data.loc[row,'revenue']=26.18
    if (col.genre_new=='Sci-fi & Fantasy')& (col.rating>=6.0) & (pd.isnull(col.revenue)):
        data.loc[row,'revenue']=100.98
    if (col.genre_new=='Sci-fi & Fantasy')& (col.rating<6.0) & (pd.isnull(col.revenue)):
        data.loc[row,'revenue']=63.40
    if (col.genre_new=='Adventure & Action')& (col.rating>=6.0) & (pd.isnull(col.revenue)):
        data.loc[row,'revenue']=85.95
    if (col.genre_new=='Adventure & Action')& (col.rating<6.0) & (pd.isnull(col.revenue)):
        data.loc[row,'revenue']=34.01
    if (col.genre_new=='Comedy')& (col.rating>=6.0) & (pd.isnull(col.revenue)):
        data.loc[row,'revenue']=42.82
    if (col.genre_new=='Comedy')& (col.rating<6.0) & (pd.isnull(col.revenue)):
        data.loc[row,'revenue']=48.24
    if (col.genre_new=='Romance')& (col.rating>=6.0) & (pd.isnull(col.revenue)):
        data.loc[row,'revenue']=42.82
    if (col.genre_new=='Romance')& (col.rating<6.0) & (pd.isnull(col.revenue)):
        data.loc[row,'revenue']=44.67

# %%
data[data['revenue'].isnull()]
# Out:
# Empty DataFrame
# Columns: [rank, title, genre, director, actors, year, runtime, rating, votes, revenue, metascore, genre_new, actor1, actor2, actor3, actor4, runtime_group]
# Index: []

# %% [markdown]
# <a name = Section16></a>
# ###### Removing null from the 'metascore' column
# We will replace the value with the mean

# %%
data['metascore'].fillna(value=58.97,inplace=True)

# %%
data[data['metascore'].isnull()]
# Out:
# Empty DataFrame
# Columns: [rank, title, genre, director, actors, year, runtime, rating, votes, revenue, metascore, genre_new, actor1, actor2, actor3, actor4, runtime_group]
# Index: []

# %% [markdown]
# <a name = Section17></a>
# ###### Creating 4 Actors columns
# As observed, Each row in the actor column has 4 actor names comma separated

# %%
data['actor1']=None
data['actor2']=None
data['actor3']=None
data['actor4']=None
for (row,col) in data.iterrows():
    l1=col.actors.split(',')
    l1.sort()
    i=0
    if len(l1)>0:
        data.loc[row,'actor1']=l1[0].strip().casefold()
    if len(l1)>1:
        data.loc[row,'actor2']=l1[1].strip().casefold()
    if len(l1)>2:
        data.loc[row,'actor3']=l1[2].strip().casefold()
    if len(l1)>3:
        data.loc[row,'actor4']=l1[3].strip().casefold()

# %%
data.head()
# Out:
#    rank                    title                     genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                director                                             actors  \
# 0            James Gunn  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# 1          Ridley Scott  Noomi Rapace, Logan Marshall-Green, Michael Fa...
# 2    M. Night Shyamalan  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# 3  Christophe Lourdelet  Matthew McConaughey,Reese Witherspoon, Seth Ma...
# 4            David Ayer  Will Smith, Jared Leto, Margot Robbie, Viola D...
#
#    year  runtime  rating   votes  revenue  metascore         genre_new  \
# 0  2014      121     8.1  757074   333.13       76.0  Sci-fi & Fantasy
# ...

# %% [markdown]
# ---
# <a name = Section7></a>
# # **7. Data Post-Profiling**
# ---
#
# - This section is emphasised on getting a report about the data after the data manipulation.
#
# - You may end up observing some new changes, so keep it under check and make right observations.

# %%
data.describe(include='all')
# Out:
#                rank     title                    genre      director  \
# count   1000.000000      1000                     1000          1000
# unique          NaN       999                      207           644
# top             NaN  The Host  Action,Adventure,Sci-Fi  Ridley Scott
# freq            NaN         2                       50             8
# mean     500.500000       NaN                      NaN           NaN
# std      288.819436       NaN                      NaN           NaN
# min        1.000000       NaN                      NaN           NaN
# 25%      250.750000       NaN                      NaN           NaN
# 50%      500.500000       NaN                      NaN           NaN
# 75%      750.250000       NaN                      NaN           NaN
# max     1000.000000       NaN                      NaN           NaN
#
#                                                    actors         year  \
# ...

# %% [markdown]
# ###### Data looks good now. We can start with our analysis
# Variable types
# Number of variables	17
# Number of observations	1000
# Numeric	7
# Categorical	10
# Revenue 0 missing values
# Metascore 0 missing values

# %% [markdown]
# ---
# <a name = Section8></a>
# # **8. Exploratory Data Analysis**
# ---

# %% [markdown]
# <a name = Section18></a>
# ###### 8.1 How many movies were released every year?

# %%
plt.figure(figsize=(20,12))
data['year'].value_counts().sort_values().plot(kind='bar',fontsize=18)
plt.title("No. of movies released per year",fontsize=18)
plt.ylabel("Total Count",fontsize=18)
plt.savefig("No. of movies per Year.png")

# %% [markdown]
# <b>Observation</b>
# No. of movies released have gradually increased till 2015.  In 2016, it almost doubled.

# %% [markdown]
# <a name = Section19></a>
# ###### 8.2 How many movies were released in genre in total?

# %%
space = np.ones(11)/10
data['genre_new'].value_counts().plot(kind='pie',  fontsize=14, autopct='%3.1f%%', wedgeprops=dict(width=0.15), 
                                       shadow=True, startangle=160, figsize=(10,10), cmap='inferno', legend=True)

plt.ylabel('Genre')
plt.title('Donut Plot showing the proportion of each genre value')
plt.savefig('Donut plot total genre.png')

# %% [markdown]
# <b>Observation:</b>
# Max no. of movies released were Adventure and Action. Second Highest was Sci-fi & Fantasy

# %% [markdown]
# <a name = Section20></a>
# ###### 8.3 How much revenue was generated per Genre?

# %%
data.groupby(['genre_new'])['revenue'].median().sort_values().plot(kind='barh', figsize=(12,8), fontsize=13, color='orange')
plt.xlabel('Median Revenue (Millions)')
plt.ylabel('Genre')
plt.title("Median revenue per Genre")
plt.savefig('3.Median revenue per Genre.png')

# %% [markdown]
# <b>Observation:</b><br>
# Even though no. of Sci-fi & Fantasy movies are less than Adventure & Action, median Revenue generated by Sci-fi & Fantasy is more/highest.<br>
# No.of Drama movies released is 3rd highest but the median revenue generated is lowest.<br>
# Comedy movies have done fairly well.<br>

# %% [markdown]
# <a name = Section21></a>
# ###### 8.4 To dig deeper into genre and revenue

# %% [markdown]
# How many movies of each genre were released each year?

# %%
data.groupby(['year','genre_new'])['genre_new'].count().unstack().plot.bar(figsize=(15,10),stacked=True)
plt.title("No. of Movies per Genre released each year")
plt.savefig('3.movies per Genre per year.png')

# %% [markdown]
# <b>Observation:</b><br>
# No. of Sci-fi and Adventure movies have always been higher than the other genres. But in 2016, there were a significant number of movies released in all genres.

# %% [markdown]
# <a name = Section22></a>
# ###### 8.5 Which Genre is most profitable?

# %%
data.groupby(['year','genre_new'])['revenue'].median().unstack().plot.line(figsize=(15,10))
plt.title("Median Revenue per Genre released each year")
plt.xlabel('Year',fontsize=14)
plt.ylabel('Revenue (Millions)',fontsize=14)
plt.savefig('3.Total Revenue per Genre per year.png')

# %% [markdown]
# <b>Observation:</b>
# Mostly Sci-fi & Fantasy Movies have done better than everyone. Next is Adventure & Action who has done fairly well. Drama Movies did well in around 2010 but they haven't done well in last few years.

# %% [markdown]
# <a name = Section23></a>
# ###### 8.6 Correlation between revenue & other parameters like rating, votes & metascore

# %%
corr_mat = data.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr_mat, annot=True, cmap='viridis')
plt.savefig('correlation.png')

# %% [markdown]
# <b>Oservation:</b>
# Number of votes, Ratings, Runtime and Metascore have positive correlation with Revenue.

# %% [markdown]
# <a name = Section24></a>
# ###### 8.7 Does a higher  movie rating predict a higher profit?

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(data=data, x='rating', y='revenue', hue='genre_new')
plt.ylabel('Revenue')
plt.xlabel('Rating')
plt.title('Rating vs Revenue')
plt.savefig('ratin revenue genre scatter.png')

# %% [markdown]
# <b>Oservation:</b>
# Higher the rating, above 6, chances of higher revenue increases.

# %% [markdown]
# <a name = Section25></a>
# ###### 8.8 What should the ideal runtime of a movie be?

# %%
plt.figure(figsize=(20,12))
data['runtime_Group'] = pd.cut(data['runtime'].dropna(),
                         [66,100,120,140,160,190],
                         labels=['66-100','100-120','120-140','140-160','160+'], include_lowest=True) # making bins of runtime 
data.groupby(['runtime_Group'])['revenue'].sum().plot.bar(color='purple',fontsize=14)
plt.ylabel('Revenue',fontsize=14)
plt.xlabel('Rating',fontsize=14)

plt.title('Rating vs Revenue')
plt.savefig('runtime revenue.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ab2b441ea5be> in <module>
# ----> 1 plt.figure(figsize=(20,12))
#       2 data['runtime_Group'] = pd.cut(data['runtime'].dropna(),
#       3                          [66,100,120,140,160,190],
#       4                          labels=['66-100','100-120','120-140','140-160','160+'], include_lowest=True) # making bins of runtime
#       5 data.groupby(['runtime_Group'])['revenue'].sum().plot.bar(color='purple',fontsize=14)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# <b>Oservation:</b>
# Ideal Runtime should be between 100 to 140 minutes.

# %% [markdown]
# <a name = Section26></a>
# ###### 8.9 Which actors should be considered for a Sci-fi & Fantasy/Adventure & Action movies?

# %%
S1 = list(data.actor1)
S2 = list(data.actor2)
S3 = list(data.actor3)
S4 = list(data.actor4)
S = S1+S2+S3+S4
S = set(S)                 # creating a set which will have all the unique actor names

# %%
P = pd.DataFrame(columns = ["Name","Count","Total_Revenue"])
for A_names in S:
    sets = [A_names]
    m = data.loc[((data['genre_new']=='Sci-fi & Fantasy')|(data['genre_new']=='Adventure & Action'))&((data['actor1'].str.replace('s/+',"")==(A_names)) | (data['actor4'].str.replace('s/+',"")==(A_names)) |(data['actor3'].str.replace('s/+',"")==(A_names)) |(data['actor2'].str.replace('s/+',"")==(A_names)))].agg({"year": "count" , "revenue": "sum"})
    # if the actor name matches and the movie belongs to Sci-fi & Fantasy or Adventure & Action genre then we sum the revenue and inc the count
    sets.append(m[0])
    sets.append(m[1])
    a_series = pd.Series(sets, index = P.columns) #putting the count, sum of revenue, actor name to series
    P = P.append(a_series, ignore_index = True)
P["Avg_Rev"] = P.Total_Revenue/P.Count 
P.sort_values(by = 'Total_Revenue', ascending = False,inplace = True)
P = P.head(10).sort_values(ascending=False,by='Avg_Rev') # storing the top 10 actor names

# %%
plt.figure(figsize=(20,12))
ax = P[["Name","Avg_Rev"]].plot( x='Name', kind='bar', figsize = (15,7))
P[["Name", "Count"]].plot(x = "Name", kind = 'line', ax = ax, secondary_y = True, linestyle='-' ,marker='X', color = "red")
plt.ylabel('revenue')
plt.title('highest revenue generating actors')
plt.savefig('top 10 actors.png')
plt.show()

# %% [raw]
# <b>Oservation:</b>
# Pierre Coffin, Chris Evans & Ben Affleck are one top three.

# %% [markdown]
# <a name = Section27></a>
# ###### 8.10 Which Directors should be prefered for a Sci-fi & Fantasy/Adventure & Action movies? Which movie director has the highest average profit?Are certain movie directors especially good at a particular genre (in terms of profit)?

# %%
S=set(data['director'].str.strip().str.casefold())
P = pd.DataFrame(columns = ["Name","Count","Total_Revenue"])
for A_names in S:
    sets = [A_names]
    m = data.loc[((data['genre_new']=='Sci-fi & Fantasy')|(data['genre_new']=='Adventure & Action'))&((data['director'].str.casefold().str.replace('s/+',"")==(A_names)))].agg({"year": "count" , "revenue": "sum"})
   # if the director name matches and the movie belongs to Sci-fi & Fantasy or Adventure & Action genre then we sum the revenue and inc the count
    sets.append(m[0])
    sets.append(m[1])
    a_series = pd.Series(sets, index = P.columns)
    P = P.append(a_series, ignore_index = True)

P.sort_values(by = 'Total_Revenue', ascending = False,inplace = True)
P = P.head(10)

# %%
P['Name'].str.capitalize().unique()
# Out:
# array(['J.j. abrams', 'David yates', 'Christopher nolan', 'Michael bay',
#        'Joss whedon', 'Francis lawrence', 'Jon favreau', 'Zack snyder',
#        'Peter jackson', 'Justin lin'], dtype=object)

# %%
plt.figure(figsize=(20,12))
ax = P[["Name","Total_Revenue"]].plot( x='Name', kind='bar', figsize = (15,7))
P[["Name", "Count"]].plot(x = "Name", kind = 'line', ax = ax, secondary_y = True, linestyle='-' ,marker='X', color = "red")
plt.ylabel('Revenue')
plt.title('Highest revenue generating Directors')
plt.savefig('highest revenue generating Directors.png')
plt.show()

# %% [markdown]
# <b>Oservation:</b>
# J.J.Abrams & David Yates are the top 2.

# %% [raw]
# ---
# <a name = Section9></a>
# # **9. Summarization**
# ---

# %% [markdown]
# <b>The collection of information from this dataset has brought to light the following:</b><br>
# <ul>
#     <li>We can see the clear correlation between box office revenue and movie genre. The action and adventure movie lead to higher revenue than other genres</li>
#     <li>Sci-Fi & Fantasy Genre as well as Adventure & Action Genre have done significantly better than other genres</li>
#     <li>Critics do not play an important role as much as we think. Therefore the article indicates those factors explain 60% of the variation in box-office revenues. hence we see that though there is a positive correlation between Metascore and Revenue but its not too high.</li>
#     <li>Rating does affect the revenue of a movie at the box office</li>
#     <li>Runtime of a movie is preferred  to be between 100-140 mins</li>
# </ul>

# %% [markdown]
# <a name = Section91></a>
# ### **9.1 Conclusion**
#
# <b>We have observed that Sci-Fi & Fantasy Genre as well as Adventure & Action Genre movies do better at the box office than any other. Lets see some of the reasons why these genres are preferred over the others.</b>
#
# <b>Why do people like to watch super hero movies?</b><br>
# Inhuman abilities, alien worlds, and bizarre situations are some of the hallmarks of our favourite superhero films. Yet these characteristics are also the ones absent from our everyday reality. This discord between superhero movies and our ordinary lives allows us to separate one from the other. Therefore, when our reality becomes too much for us to bear, we can escape to the world of the mighty Thor and his friends.<br>
# We’re Psychologically Wired to Love Those Who Protect the Weak.<br>
# Psychologist Robin S. Rosenberg defines a superhero as someone who has superhuman powers and does heroic deeds by exhibiting “brave and self-sacrificing” behaviour. This idea of courage and selflessness, which we associate with our favourite superheroes, is often translated onscreen as superheroes using their insane abilities for the protection of ordinary humans<br>
#
# <b>Why to chose Sci-fi movies</b><br>
# <i>Science fiction is the perfect source of inspiration</i><br>
# Sci-fi stories can be set far in the future, they can take place on distant worlds. But, really, they’re about the issues that affect us in the here and now.<br>
# Science fiction has been around for a long time of course, but rather than guessing at random possibilities like some of the old masters had to do (and they did it superbly well), every writer is blessed with a good sense of the direction in which space exploration is heading, the tech we’ll probably use to travel, and even what many planets in our solar system will be like when we get there.<br>
# These notions do not constrain storytelling, they direct and refine it. They allow sci-fi writers to put characters in situations that are literally out of this world (but still totally plausible), and to explore how they respond.
# Some people believe that sci-fi genre is good for literary and cultural progress. Sci-fi is renowned for breaking new ground (for example War of the Worlds considered the horror of military invasion through depicting a Martian invasion of Earth) and being amongst the first genres to truly embrace character diversity <br>
# People watch sci-fi to feel awe and they want to be left with a thought-provoking concept. What would I do if I met my clone? What might aliens really look like? How would I survive in a robot apocalypse? How can the time-travel grandfather paradox be resolved? But at the end of the day, people want a story that resonates with me emotionally.<br>
#
# <b>Action movies and Adventure</b><br>
# <i> Action films is all about larger than life visions.</i>  Action movie will definitely have a bad guy, some impossible tasks, a beautiful heroine and at the end hero will win over all the obstacles and even win his lady love. So at the end the person who watched the movie goes out with a sense of accomplishment and confidence (as if he is the one who did the fights and stunts….).<br>
#     They like adventure movies because it can keep them on the edge of their seat and they can feel like themselves are in the adventure too<br>
# The ratings are issued by the Motion Picture Association of America’s (MPAA) Classification and Rating Administration prior to a movie’s release to provide parents with guidelines as they decide what films their children should see. The board makes its decisions on the basis of graphic sex or violence, drug use and dark themes without regard to box office impact.
# It’s a numbers game. Young and older men and women — “all four quadrants” as they’re known in the industry — can attend a G, PG or PG-13 movie. But an R-rated movie, which requires an adult to accompany anyone under 17, has a necessarily smaller potential audience.<br>
# The box office bears that out. <b>Movies rated R returned about $42 at the box office. While the average haul of PG ($82 million) and PG-13 movies ($79 million) was roughly double that. </b>
# With superheroes like the Avengers, the X-Men, Spider-Man, Thor and the Guardians of the Galaxy leading a seemingly endless parade of Marvel blockbusters, it’s no surprise PG-13 is the ratings classification showing the biggest returns.

# %% [markdown]
# <a name = Section92></a>
# ### **9.2 Actionable Insights**
# Lionsgate needs to up their game to come in the list of top 5 production houses as well as get more n more movies in top 50 list. Inorder do to that they can follow below solutions:
# <ul>
#     <li>
# Sequels and franchise films limit the risks of low revenue. Nearly one in five of the films produced in Hollywood is a sequel. All other factors being equal, sequels earn $35m more than Nonsquels at the box office. For example, a $200 million budget superhero movie will earn $58 million more at the box office than the non-superhero movie of the same budget. Superhero movies (except “Deadpool”) are often child-friendly for a good reason: movies that receive an “R” (restricted) certificate typically have a $16 million reduction in cinema revenue.<br></li>
#     <li>As <b>Walt Disney Studios chairman Alan Horn</b> says'So whether it’s a franchise film or a brand-new concept, it is absolutely essential that we create compelling content that gets people to stop everything else they’re doing and go to the theater.”'<br>
#         So Lionsgate  must take up a project which belongs to <i>Sci-fi genre</i> along with a story line which has Adventure involved. It will also make a difference if its has an element of comedy, which lightens the mood and relaxes people</br>
#      </li>
# <li>Some people believe that if Hollywood wants to avoid this kind of criticism in the future, it needs to put an end to whitewashed casting, once and for all. It will be a good idea to have a mix of white and black actors. </li>
# <li>We also have a list of top 10 directors who have directed Sci-fi or Adventure & Action genre movies to select from with J.J.Abrams & David Yates among the top 2</li>
# </ul>
#
# <b>Overall, we must go for a movie which can e enjoyed by a wider agegroup, people can enjoy with their family, a movie which gives them hope of a better tomorrow and which gives them a feeling that if they face any problem they will be ale to solve it and come out victorious.
